# %% [markdown]
# # 6.6 Sourcing & Analyzing Time-Series Data

# %% [markdown]
# ### This script contains the following:
#
# #### 1. Importing your libraries and data
# #### 2. Subsetting, wrangling, and cleaning time-series data
# #### 3. Time series analysis: decomposition
# #### 4. Testing for stationarity
# #### 5. Stationarizing the Data

# %% [markdown]
# ### 1. Importing your libraries and data

# %% [markdown]
# Before you start this analysis, you'll need a new library you haven't installed before—Quandl. Install Quandl using conda:
#
# `conda install quandl`

# %%
# !pip install quandl
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm # Using .api imports the public access version of statsmodels, which is a library that handles 
# statistical models.
import os
import warnings # This is a library that handles warnings.

warnings.filterwarnings("ignore") # Disable deprecation warnings that could indicate, for instance, a suspended library or 
# feature. These are more relevant to developers and very seldom to analysts.

plt.style.use('fivethirtyeight') # This is a styling option for how your plots will appear. More examples here:
# https://matplotlib.org/3.2.1/tutorials/introductory/customizing.html
# https://matplotlib.org/3.1.0/gallery/style_sheets/fivethirtyeight.html

# %%
# Configure API key 

#quandl.ApiConfig.api_key = 'yourAPIkey'

quandl.ApiConfig.api_key = 'KdYqfBRyPsQpjZ9AeNAG'

# %%
# Importing the Federal Reserve Econimic Data 
# Industrial Production: Durable Goods: Ship and Boat Buiding variable 

data = quandl.get('FRED/IPG3366NQ')

# %%
# Look at data

data.head(10)
# Out:
#               Value
# Date
# 1972-01-01  68.9357
# 1972-04-01  71.3349
# 1972-07-01  70.2776
# 1972-10-01  73.8011
# 1973-01-01  76.4671
# 1973-04-01  77.8645
# 1973-07-01  77.4795
# 1973-10-01  80.0359
# 1974-01-01  76.9991
# 1974-04-01  76.7627

# %%
data.tail(5)
# Out:
#                Value
# Date
# 2020-10-01   96.0491
# 2021-01-01  101.2051
# 2021-04-01   97.5764
# 2021-07-01   97.0356
# 2021-10-01  102.2605

# %%
data.shape
# Out:
# (200, 1)

# %%
data.columns
# Out:
# Index(['Value'], dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Plot the data using matplotlib. to see what data looks like

plt.figure(figsize=(15,5), dpi=100) # The dpi argument controls the quality of the visualization here. When it's set to 100,
# it will produce lower-than-standard quality, which is useful if, similar to this notebook, you'll have a lot of plots.
# A large number of plots will increase the size of the notebook, which could take more time to load and eat up a lot of RAM!

plt.plot(data)

# %% [markdown]
# Data includes observations from around 1972 to present day, will use data from 2000 forward.

# %% [markdown]
# ### 2. Subsetting, wrangling, and cleaning time-series data

# %%
# Reset index so that you can use the "Date" column as a filter

data_2 = data.reset_index()

# %%
data_2.head()
# Out:
#         Date    Value
# 0 1972-01-01  68.9357
# 1 1972-04-01  71.3349
# 2 1972-07-01  70.2776
# 3 1972-10-01  73.8011
# 4 1973-01-01  76.4671

# %%
# Create new subset from 2004 forward
data_sub = data_2.loc[(data_2['Date'] >= '2000-01-01')] ## & (data_2['Date'] < '2023-03-01')]

# %%
data_sub.shape
# Out:
# (88, 2)

# %%
# Set the "Date" column as the index replot new data sub

from datetime import datetime

data_sub['datetime'] = pd.to_datetime(data_sub['Date']) # Create a datetime column from "Date.""
data_sub = data_sub.set_index('datetime') # Set the datetime as the index of the dataframe.
data_sub.drop(['Date'], axis=1, inplace=True) # Drop the "Date" column.
data_sub.head()
# Out:
#               Value
# datetime
# 2000-01-01  83.1197
# 2000-04-01  82.0345
# 2000-07-01  79.4132
# 2000-10-01  79.4405
# 2001-01-01  78.2262

# %%
# Plot the new data set

plt.figure(figsize=(15,5), dpi=100)
plt.plot(data_sub)

# %%
# Check for missing values (you shouldn't have any)

data_sub.isnull().sum()
# Out:
# Value    0
# dtype: int64

# %%
# Check for duplicates

dups = data_sub.duplicated()
dups.sum()

# 0 dups!
# Out:
# 0

# %% [markdown]
# ### 3. Time-series analysis: decomposition

# %%
# Decompose the time series using an additive model

decomposition = sm.tsa.seasonal_decompose(data_sub, model='additive')

# %%
from pylab import rcParams # This will define a fixed size for all special charts.

rcParams['figure.figsize'] = 18, 7

# %%
# Plot the separate components

decomposition.plot()

plt.savefig("Decomposition")
plt.show()

# %%
# What is current directory saving to
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\dolson\\OneDrive - BEACON TECHNOLOGIES\\Desktop\\Achievement6\\03 Scripts'

# %% [markdown]
# ### 4. Testing for stationarity

# %%
# The adfuller() function will import from the model from statsmodels for the test; however, running it will only return 
# an array of numbers. This is why you need to also define a function that prints the correct output from that array.

from statsmodels.tsa.stattools import adfuller # Import the adfuller() function

def dickey_fuller(timeseries): # Define the function
    # Perform the Dickey-Fuller test:
    print ('Dickey-Fuller Stationarity test:')
    test = adfuller(timeseries, autolag='AIC')
    result = pd.Series(test[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
    for key,value in test[4].items():
       result['Critical Value (%s)'%key] = value
    print (result)

# Apply the test using the function on the time series
dickey_fuller(data_sub['Value'])
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -2.386576
# p-value                         0.145561
# Number of Lags Used             8.000000
# Number of Observations Used    79.000000
# Critical Value (1%)            -3.515977
# Critical Value (5%)            -2.898886
# Critical Value (10%)           -2.586694
# dtype: float64

# %% [markdown]
# In this case using a significance level of 5%, look at critical value (5%)-2.89 in this example.  This is smaller (not much) than the text statistic of -2.38, meaning that  the null hypothesis can't be rejected.  Meaning that there is a unit root in the data and the data is non-stationary.

# %%
# Check out a plot of autocorrelations

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf # Here, you import the autocorrelation and partial correlation plots

plot_acf(data_sub)
plt.savefig("Autocorrelations")
plt.show()

# %% [markdown]
# Vertical lines represent the lags in the series, with the blue area representing the confidence interval.  The lines that go above the blue edge are lags significantly correlated with each other. There are 4 lines above the confidence interval (blue area), indicating lags correlated with each other meaning that there is autocorrelated data, confirming that the data set is likely non-stationary(has a trend), supporting the Dickey-Fuller test conducted earlier.
# Can't forecast with non-stationary data so need to make it stationary by removing any unnecessary variance.

# %% [markdown]
# ### 5. Stationarizing the Industrial Production Durable Goods: Ship and boat Building data

# %%
# Differencing - calculate the difference btwn every value (t) and 
# its lag (t-1), store new results in a new dataframe

data_diff = data_sub - data_sub.shift(1) # The df.shift(1) function turns the observation to t-1, making the whole thing t - (t -1)

# %%
data_diff.dropna(inplace = True) # Here, you remove the missing values that came about as a result of the differencing. 
# You need to remove these or you won't be able to run the Dickey-Fuller test.

# %%
data_diff.head()
# Out:
#              Value
# datetime
# 2000-04-01 -1.0852
# 2000-07-01 -2.6213
# 2000-10-01  0.0273
# 2001-01-01 -1.2143
# 2001-04-01 -0.8511

# %%
data_diff.columns
# Out:
# Index(['Value'], dtype='object')

# %%
# Check out what the differencing did to the time-series curve

plt.figure(figsize=(15,5), dpi=100)
plt.plot(data_diff)

# %%
dickey_fuller(data_diff)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -5.152980
# p-value                         0.000011
# Number of Lags Used             6.000000
# Number of Observations Used    80.000000
# Critical Value (1%)            -3.514869
# Critical Value (5%)            -2.898409
# Critical Value (10%)           -2.586439
# dtype: float64

# %% [markdown]
# The Critical values are less than the Test Statistic , and a satisfactory p-value <0.05 so data is now stationary and null hypothesis can be rejected.

# %%
# Recheck autocorrelations
plot_acf(data_diff)
plt.savefig("Autocorrelation2")
plt.show()

# %% [markdown]
# The autocorrelation plot has improved, but there are still a few lines (3) above the confidence interval (blue area), meaning that the data stationary is weak.  But this meets the " unspoken rule of thumb" , that you need at least 10 significant lags (10 vertical lines above the confidence interval).
